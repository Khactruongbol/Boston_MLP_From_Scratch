# %% [markdown]
# # Lab 4 - Boston Housing Model Report
#
# Notebook n?y ???c vi?t l?i theo d?ng b?o c?o t?ng h?p t??ng t? c?c lab tr??c. Theo y?u c?u, notebook kh?ng ch?a code cell; n?i dung ch?nh l? c?c h?nh ?nh k?t qu? sau khi train v? ki?m tra ch??ng tr?nh.

# %% [markdown]
# ## 1. T?ng quan k?t qu? train model
#
# ![B?ng metric so s?nh model](../reports/figures/model_metrics_table.png)

# %% [markdown]
# ## 2. Ch?n model t?i ?u
#
# Model t?i ?u ???c ch?n theo RMSE th?p nh?t tr?n c?ng t?p test.
#
# ![So s?nh RMSE gi?a c?c model](../reports/figures/model_rmse_comparison.png)

# %% [markdown]
# ## 3. Best model: Random Forest Regression
#
# ![Actual vs Predicted - Random Forest Regression](../reports/figures/actual_vs_predicted_random_forest_regression.png)
#
# ![Feature importance c?a best model](../reports/figures/best_model_feature_importance.png)

# %% [markdown]
# ## 4. MLP Regression
#
# ![Actual vs Predicted - MLP Regression](../reports/figures/actual_vs_predicted_mlp_regression.png)
#
# ![MLP training curve](../reports/figures/mlp_training_curve.png)

# %% [markdown]
# ## 5. Baseline models
#
# ![Actual vs Predicted - Linear Regression](../reports/figures/actual_vs_predicted_linear_regression.png)
#
# ![Actual vs Predicted - Decision Tree Regression](../reports/figures/actual_vs_predicted_decision_tree_regression.png)

# %% [markdown]
# ## 6. Ki?m tra y?u c?u b?i to?n
#
# ![Checklist ki?m tra to?n b? ch??ng tr?nh](../reports/figures/project_validation_summary.png)

# %% [markdown]
# ## 7. K?t lu?n
#
# Notebook ?nh-only n?y s? d?ng tr?c ti?p c?c artifact ???c t?o t? ch??ng tr?nh trong `src/train.py`. K?t qu? ki?m tra cho th?y ch??ng tr?nh ?? c? raw data, clean data, chia feature/target, train/test c?c model, ch?n best model, l?u ?nh, l?u model t?t nh?t v? c? giao di?n Python trong `app.py`.
